# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset/survey_results_public.csv')
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
print((df.shape))
# Out:
# (89184, 84)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  str
#  2   MainBranch                           89184 non-null  str
#  3   Age                                  89184 non-null  str
#  4   Employment                           87898 non-null  str
#  5   RemoteWork                           73810 non-null  str
#  6   CodingActivities                     73764 non-null  str
#  7   EdLevel                              87973 non-null  str
#  8   LearnCode                            87663 non-null  str
#  9   LearnCodeOnline                      70084 non-null  str
#  10  LearnCodeCoursesCert                 37076 non-null  str
# ...

# %%
pd.set_option('display.max_columns',84)
df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
schema_df = pd.read_csv('dataset/survey_results_schema.csv')
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
print(list(schema_df.columns))
# Out:
# ['qid', 'qname', 'question', 'force_resp', 'type', 'selector']

# %%
print(schema_df['qname'])
print(type(schema_df['qname']))
# Out:
# 0              S0
# 1        MetaInfo
# 2            Q310
# 3            Q120
# 4              S1
#          ...
# 73    Knowledge_7
# 74    Knowledge_8
# 75    Frequency_1
# 76    Frequency_2
# 77    Frequency_3
# Name: qname, Length: 78, dtype: str
# <class 'pandas.Series'>

# %%
schema_df[["question","type"]]
# Out:
#                                              question  type
# 0   <div><span style="font-size:19px;"><strong>Hel...    DB
# 1                                   Browser Meta Info  Meta
# 2   <div><span style="font-size:19px;"><strong>You...    DB
# 3                                                        MC
# 4   <span style="font-size:22px; font-family: aria...    DB
# ..                                                ...   ...
# 73  Waiting on answers to questions often causes i...    MC
# 74  I feel like I have the tools and/or resources ...    MC
# 75  Needing help from people outside of your immed...    MC
# 76  Interacting with people outside of your immedi...    MC
# 77  Encountering knowledge silos (where one indivi...    MC
#
# [78 rows x 2 columns]

# %%
print(type(schema_df[["question","type"]]))
# Out:
# <class 'pandas.DataFrame'>

# %%
schema_df['question'].loc[4]
# Out:
# '<span style="font-size:22px; font-family: arial,helvetica,sans-serif; font-weight: 700;">Basic Information</span><br>\n<br>\n<p><span style="font-size:16px; font-family:arial,helvetica,sans-serif;">The first section will focus on some basic information about who you are.<br>\n<br>\nMost questions in this section are required. Required questions are noted with *.</span></p>'

# %%
schema_df.iloc[:2,[0,1,2]]
# Out:
#      qid     qname                                           question
# 0  QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1  QID12  MetaInfo                                  Browser Meta Info

# %%
schema_df.loc[[0,1,2],["qid","qname"]]
# Out:
#       qid     qname
# 0   QID16        S0
# 1   QID12  MetaInfo
# 2  QID310      Q310

# %% [markdown]
# Now i want to know how much are from USA.

# %%
country_arr = np.array(df["Country"])

country_arr = country_arr[country_arr == "United States of America"]
print(country_arr.size)
# Out:
# 18647

# %%
pd.set_option('display.max_rows',10)

df["Country"].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %% [markdown]
# Indexing

# %%
schema_df.info()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qid         78 non-null     str
#  1   qname       78 non-null     str
#  2   question    78 non-null     str
#  3   force_resp  67 non-null     object
#  4   type        78 non-null     str
#  5   selector    78 non-null     str
# dtypes: object(1), str(5)
# memory usage: 3.8+ KB
# <class 'pandas.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  str
#  2   MainBranch                           89184 non-null  str
#  3   Age                                  89184 non-null  str
# ...

# %%
schema_df.set_index('qname')
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# Q310         QID310  <div><span style="font-size:19px;"><strong>You...
# Q120         QID312
# S1             QID1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# Knowledge_7  QID289  Waiting on answers to questions often causes i...
# Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# Frequency_1  QID290  Needing help from people outside of your immed...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# ...

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
schema_df.index
# Out:
# RangeIndex(start=0, stop=78, step=1)

# %%
schema_df.set_index("qname",inplace = True)

# %%
schema_df
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# Q310         QID310  <div><span style="font-size:19px;"><strong>You...
# Q120         QID312
# S1             QID1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# Knowledge_7  QID289  Waiting on answers to questions often causes i...
# Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# Frequency_1  QID290  Needing help from people outside of your immed...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# ...

# %%
schema_df.nunique() #ignoring NaN
# Out:
# qid           67
# question      78
# force_resp     2
# type           6
# selector       8
# dtype: int64

# %%
schema_df['force_resp'].unique()
# Out:
# array([False, True, nan], dtype=object)

# %%
schema_df['force_resp'].nunique()
# Out:
# 2

# %%
schema_df.index
# Out:
# Index(['S0', 'MetaInfo', 'Q310', 'Q120', 'S1', 'MainBranch', 'Age',
#        'Employment', 'RemoteWork', 'CodingActivities', 'S2', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'TechList',
#        'BuyNewTool', 'Country', 'Currency', 'CompTotal', 'S3', 'Language',
#        'Database', 'Platform', 'Webframe', 'MiscTech', 'ToolsTech',
#        'NEWCollabTools', 'OpSys', 'OfficeStackAsync', 'OfficeStackSync',
#        'AISearch', 'AIDev', 'S4', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOComm', 'S5', 'SOAI', 'AISelect', 'AISent', 'AIAcc',
#        'AIBen', 'AITool', 'AINext', 'AIOpen', 'S6', 'TBranch', 'ICorPM',
#        'WorkExp', 'Knowledge', 'Frequency', 'TimeSearching', 'TimeAnswering',
#        'ProfessionalTech', 'Industry', 'SOTeamsUsage', 'S7', 'SurveyLength',
#        'SurveyEase', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3',
# ...

# %%
schema_df.loc["Country",["qid","question","force_resp"]]
# Out:
# qid                                                        QID6
# question      Where do you live? <span style="font-weight: b...
# force_resp                                                 True
# Name: Country, dtype: object

# %%
schema_df.iloc[0] # iloc will still work even after changing indexing
# Out:
# qid                                                       QID16
# question      <div><span style="font-size:19px;"><strong>Hel...
# force_resp                                                False
# type                                                         DB
# selector                                                     TB
# Name: S0, dtype: object

# %%
schema_df.reset_index(inplace = True)

# %%
schema_df.index
# Out:
# RangeIndex(start=0, stop=78, step=1)

# %% [markdown]
# Filtering

# %%
filt = schema_df["force_resp"]==True
print(filt)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Name: force_resp, Length: 78, dtype: bool

# %%
schema_df[filt]
# Out:
#          qname     qid                                           question  \
# 3         Q120  QID312
# 5   MainBranch    QID2  Which of the following options best describes ...
# 6          Age  QID127                                What is your age? *
# 11     EdLevel   QID25  Which of the following best describes the high...
# 22     Country    QID6  Where do you live? <span style="font-weight: b...
# 23    Currency   QID50  Which currency do you use day-to-day? If your ...
# 39  NEWSOSites  QID266  Which of the following Stack Overflow sites ha...
# 46    AISelect  QID314  Do you currently use AI tools in your developm...
# 54     TBranch  QID299  <span style="font-size:16px;">Would you like t...
#
#    force_resp type selector
# 3        True   MC     SAVR
# 5        True   MC     SAVR
# 6        True   MC     MAVR
# 11       True   MC     SAVR
# 22       True   MC       DL
# 23       True   MC       DL
# 39       True   MC     MAVR
# 46       True   MC     SAVR
# ...

# %%
schema_df.loc[filt,["qname","question"]]
# Out:
#          qname                                           question
# 3         Q120
# 5   MainBranch  Which of the following options best describes ...
# 6          Age                                What is your age? *
# 11     EdLevel  Which of the following best describes the high...
# 22     Country  Where do you live? <span style="font-weight: b...
# 23    Currency  Which currency do you use day-to-day? If your ...
# 39  NEWSOSites  Which of the following Stack Overflow sites ha...
# 46    AISelect  Do you currently use AI tools in your developm...
# 54     TBranch  <span style="font-size:16px;">Would you like t...

# %%
schema_df.loc[(schema_df["force_resp"]==True) & (schema_df["selector"]=="DL"),["qname","question"]]
# Out:
#        qname                                           question
# 22   Country  Where do you live? <span style="font-weight: b...
# 23  Currency  Which currency do you use day-to-day? If your ...

# %%
df.loc[((df["CompTotal"]>100000) & (df["Country"].isin(["India"])) & (df["LanguageHaveWorkedWith"].str.contains("Python",na = False)) ),["Age","EdLevel","LanguageHaveWorkedWith","DevType","ToolsTechHaveWorkedWith","CompTotal"]].head(20)
# Out:
#                   Age                                            EdLevel  \
# 209   18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 271   18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 314   25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 377   35-44 years old  Some college/university study without earning ...
# 397   18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...               ...                                                ...
# 1459  18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1665  25-34 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 1817  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1904  18-24 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2555  18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                  LanguageHaveWorkedWith  \
# ...

# %% [markdown]
# Renaming Column

# %%
print(type(schema_df.columns))
schema_df.columns = [x.upper() for x in schema_df.columns]
print(type(schema_df.columns))
schema_df.head(2)
# Out:
# <class 'pandas.Index'>
# <class 'pandas.Index'>
#       QNAME    QID                                           QUESTION  \
# 0        S0  QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1  MetaInfo  QID12                                  Browser Meta Info
#
#   FORCE_RESP  TYPE SELECTOR
# 0      False    DB       TB
# 1      False  Meta  Browser

# %%
schema_df.columns = schema_df.columns.str.capitalize()
schema_df.head(2)
# Out:
#       Qname    Qid                                           Question  \
# 0        S0  QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1  MetaInfo  QID12                                  Browser Meta Info
#
#   Force_resp  Type Selector
# 0      False    DB       TB
# 1      False  Meta  Browser

# %%
schema_df.rename(columns = {"Force_resp" : "Force resp"},inplace= True)
schema_df.head(2)
# Out:
#       Qname    Qid                                           Question  \
# 0        S0  QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1  MetaInfo  QID12                                  Browser Meta Info
#
#   Force resp  Type Selector
# 0      False    DB       TB
# 1      False  Meta  Browser

# %% [markdown]
# Row Update

# %%
def age_checker (age_dtls : str) :
    ls = age_dtls.split("years")
    return ls[0]
  

df['Age'] = df['Age'].apply(age_checker)
df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#       Age                                         Employment  \
# 0  18-24                                                 NaN
# ...

# %%
schema_df
# Out:
#           Qname     Qid                                           Question  \
# 0            S0   QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1      MetaInfo   QID12                                  Browser Meta Info
# 2          Q310  QID310  <div><span style="font-size:19px;"><strong>You...
# 3          Q120  QID312
# 4            S1    QID1  <span style="font-size:22px; font-family: aria...
# ..          ...     ...                                                ...
# 73  Knowledge_7  QID289  Waiting on answers to questions often causes i...
# 74  Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# 75  Frequency_1  QID290  Needing help from people outside of your immed...
# 76  Frequency_2  QID290  Interacting with people outside of your immedi...
# 77  Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#    Force resp  Type Selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
schema_df.loc[schema_df['Force resp'] == True,'Force resp'] = schema_df.loc[schema_df['Force resp'] == True,'Force resp'].replace({True : False})

schema_df
# Out:
#           Qname     Qid                                           Question  \
# 0            S0   QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1      MetaInfo   QID12                                  Browser Meta Info
# 2          Q310  QID310  <div><span style="font-size:19px;"><strong>You...
# 3          Q120  QID312
# 4            S1    QID1  <span style="font-size:22px; font-family: aria...
# ..          ...     ...                                                ...
# 73  Knowledge_7  QID289  Waiting on answers to questions often causes i...
# 74  Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# 75  Frequency_1  QID290  Needing help from people outside of your immed...
# 76  Frequency_2  QID290  Interacting with people outside of your immedi...
# 77  Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#    Force resp  Type Selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %% [markdown]
# Column delete or add

# %%
schema_df['qid_name'] = schema_df['Qid']+"-"+schema_df['Qname']
schema_df
# Out:
#           Qname     Qid                                           Question  \
# 0            S0   QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1      MetaInfo   QID12                                  Browser Meta Info
# 2          Q310  QID310  <div><span style="font-size:19px;"><strong>You...
# 3          Q120  QID312
# 4            S1    QID1  <span style="font-size:22px; font-family: aria...
# ..          ...     ...                                                ...
# 73  Knowledge_7  QID289  Waiting on answers to questions often causes i...
# 74  Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# 75  Frequency_1  QID290  Needing help from people outside of your immed...
# 76  Frequency_2  QID290  Interacting with people outside of your immedi...
# 77  Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#    Force resp  Type Selector            qid_name
# 0       False    DB       TB            QID16-S0
# ...

# %%
schema_df[['Q','QNO']]=schema_df['Qid'].str.split('QID',expand=True)
schema_df
# Out:
#           Qname     Qid                                           Question  \
# 0            S0   QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1      MetaInfo   QID12                                  Browser Meta Info
# 2          Q310  QID310  <div><span style="font-size:19px;"><strong>You...
# 3          Q120  QID312
# 4            S1    QID1  <span style="font-size:22px; font-family: aria...
# ..          ...     ...                                                ...
# 73  Knowledge_7  QID289  Waiting on answers to questions often causes i...
# 74  Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# 75  Frequency_1  QID290  Needing help from people outside of your immed...
# 76  Frequency_2  QID290  Interacting with people outside of your immedi...
# 77  Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#    Force resp  Type Selector            qid_name Q   QNO
# 0       False    DB       TB            QID16-S0      16
# ...

# %%
schema_df.drop(columns=['qid_name','Q'],inplace= True)
schema_df
# Out:
#           Qname     Qid                                           Question  \
# 0            S0   QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1      MetaInfo   QID12                                  Browser Meta Info
# 2          Q310  QID310  <div><span style="font-size:19px;"><strong>You...
# 3          Q120  QID312
# 4            S1    QID1  <span style="font-size:22px; font-family: aria...
# ..          ...     ...                                                ...
# 73  Knowledge_7  QID289  Waiting on answers to questions often causes i...
# 74  Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# 75  Frequency_1  QID290  Needing help from people outside of your immed...
# 76  Frequency_2  QID290  Interacting with people outside of your immedi...
# 77  Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#    Force resp  Type Selector  QNO
# 0       False    DB       TB   16
# 1       False  Meta  Browser   12
# ...

# %% [markdown]
# Row insert or Delete

# %%
schema_df = pd.concat([schema_df,pd.DataFrame([{"qid" : "QID99"}])],ignore_index= True)
schema_df
# Out:
#           Qname     Qid                                           Question  \
# 0            S0   QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1      MetaInfo   QID12                                  Browser Meta Info
# 2          Q310  QID310  <div><span style="font-size:19px;"><strong>You...
# 3          Q120  QID312
# 4            S1    QID1  <span style="font-size:22px; font-family: aria...
# ..          ...     ...                                                ...
# 74  Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# 75  Frequency_1  QID290  Needing help from people outside of your immed...
# 76  Frequency_2  QID290  Interacting with people outside of your immedi...
# 77  Frequency_3  QID290  Encountering knowledge silos (where one indivi...
# 78          NaN     NaN                                                NaN
#
#    Force resp  Type Selector  QNO    qid
# 0       False    DB       TB   16    NaN
# ...

# %%
schema_df.drop(index = schema_df.loc[schema_df["qid"] == "QID99"].index , inplace=True)
schema_df
# Out:
#           Qname     Qid                                           Question  \
# 0            S0   QID16  <div><span style="font-size:19px;"><strong>Hel...
# 1      MetaInfo   QID12                                  Browser Meta Info
# 2          Q310  QID310  <div><span style="font-size:19px;"><strong>You...
# 3          Q120  QID312
# 4            S1    QID1  <span style="font-size:22px; font-family: aria...
# ..          ...     ...                                                ...
# 73  Knowledge_7  QID289  Waiting on answers to questions often causes i...
# 74  Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# 75  Frequency_1  QID290  Needing help from people outside of your immed...
# 76  Frequency_2  QID290  Interacting with people outside of your immedi...
# 77  Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#    Force resp  Type Selector  QNO  qid
# 0       False    DB       TB   16  NaN
# ...

# %% [markdown]
# Sorting

# %%
df['CompTotal'].sort_values() #YearsCode
# Out:
# 88949    0.0
# 28649    0.0
# 28915    0.0
# 28575    0.0
# 8998     0.0
#         ...
# 89173    NaN
# 89176    NaN
# 89180    NaN
# 89181    NaN
# 89182    NaN
# Name: CompTotal, Length: 89184, dtype: float64

# %%
df.sort_values(by = ['CompTotal','YearsCode'],ascending=[False,True],inplace= True)

# %%
df
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 56322       56323  I agree                     I am a developer by profession
# 18463       18464  I agree                     I am a developer by profession
# 49553       49554  I agree  I am not primarily a developer, but I write co...
# 43556       43557  I agree                     I am a developer by profession
# 35779       35780  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 88883       88884  I agree                     I am a developer by profession
# 88940       88941  I agree                              I am learning to code
# 89028       89029  I agree                                      None of these
# 89134       89135  I agree                        I code primarily as a hobby
# 89159       89160  I agree                                      None of these
#
# ...

# %%
df['CompTotal'].nlargest(10)
# Out:
# 56322    5.000000e+46
# 18463    1.000000e+21
# 49553    1.000000e+16
# 43556    1.000000e+16
# 35779    1.000000e+15
# 15439    4.567887e+12
# 33078    1.000000e+11
# 19679    2.239672e+10
# 56853    1.980000e+10
# 9175     1.840199e+10
# Name: CompTotal, dtype: float64

# %%
df['CompTotal'].nsmallest(10)
# Out:
# 4350     0.0
# 56111    0.0
# 60083    0.0
# 4465     0.0
# 26478    0.0
# 30461    0.0
# 37641    0.0
# 49933    0.0
# 65647    0.0
# 73797    0.0
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10,'CompTotal')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 56322       56323  I agree                     I am a developer by profession
# 18463       18464  I agree                     I am a developer by profession
# 49553       49554  I agree  I am not primarily a developer, but I write co...
# 43556       43557  I agree                     I am a developer by profession
# 35779       35780  I agree                     I am a developer by profession
# 15439       15440  I agree                     I am a developer by profession
# 33078       33079  I agree                     I am a developer by profession
# 19679       19680  I agree                     I am a developer by profession
# 56853       56854  I agree  I am not primarily a developer, but I write co...
# 9175         9176  I agree                     I am a developer by profession
#
#           Age                                         Employment RemoteWork  \
# ...

# %% [markdown]
# Aggregate & join

# %%
df['CompTotal'].describe()
# Out:
# count    4.822500e+04
# mean     1.036807e+42
# std      2.276847e+44
# min      0.000000e+00
# 25%      6.300000e+04
# 50%      1.150000e+05
# 75%      2.300000e+05
# max      5.000000e+46
# Name: CompTotal, dtype: float64

# %%
df['CompTotal'].max()
# Out:
# np.float64(4.999999999999999e+46)

# %%
df.groupby('Country')[['RemoteWork','YearsCode']].count()
# Out:
#                                       RemoteWork  YearsCode
# Country
# Afghanistan                                   42         59
# Albania                                       50         56
# Algeria                                       50         82
# Andorra                                       13         15
# Angola                                         9         11
# ...                                          ...        ...
# Venezuela, Bolivarian Republic of...          87        106
# Viet Nam                                     265        381
# Yemen                                         17         20
# Zambia                                        18         26
# Zimbabwe                                      17         33
#
# [185 rows x 2 columns]

# %%
df.groupby('Country')['Employment'].value_counts()
# Out:
# Country      Employment
# Afghanistan  Employed, full-time                                                                                           22
#              Independent contractor, freelancer, or self-employed                                                           8
#              Not employed, but looking for work                                                                             5
#              I prefer not to say                                                                                            5
#              Student, full-time                                                                                             4
#                                                                                                                            ..
# Zimbabwe     Not employed, but looking for work;Employed, part-time                                                         1
# ...

# %%
df.groupby('Country')['Employment'].value_counts()['India'].sort_values(ascending = False)
# Out:
# Employment
# Employed, full-time                                                                                                               3273
# Student, full-time                                                                                                                 800
# Independent contractor, freelancer, or self-employed                                                                               290
# Not employed, but looking for work                                                                                                 270
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                           193
#                                                                                                                                   ...
# Employed, full-time;Student, full-time;Employed, part-time                                                                           1
# ...

# %%
df[df['Employment']== 'Employed, full-time'].groupby('Country')['ConvertedCompYearly'].agg(['min','max'])
# Out:
#                                           min        max
# Country
# Afghanistan                              33.0  9203683.0
# Albania                                  14.0   139700.0
# Algeria                                 512.0    37776.0
# Andorra                               23560.0   289142.0
# Angola                                  662.0     7942.0
# ...                                       ...        ...
# Venezuela, Bolivarian Republic of...      5.0   180000.0
# Viet Nam                                  1.0   107090.0
# Yemen                                  9000.0    59917.0
# Zambia                                 4036.0    41122.0
# Zimbabwe                               3000.0   114000.0
#
# [176 rows x 2 columns]

# %% [markdown]
# can you guess what percent of people in each country knows python

# %%
df
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 56322       56323  I agree                     I am a developer by profession
# 18463       18464  I agree                     I am a developer by profession
# 49553       49554  I agree  I am not primarily a developer, but I write co...
# 43556       43557  I agree                     I am a developer by profession
# 35779       35780  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 88883       88884  I agree                     I am a developer by profession
# 88940       88941  I agree                              I am learning to code
# 89028       89029  I agree                                      None of these
# 89134       89135  I agree                        I code primarily as a hobby
# 89159       89160  I agree                                      None of these
#
# ...

# %%
df.groupby(['Country'])['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').value_counts(normalize = True))
# Out:
# Country
# Afghanistan  False    0.656250
#              True     0.343750
# Albania      False    0.683333
#              True     0.316667
# Algeria      False    0.588235
#                         ...
# Yemen        True     0.400000
# Zambia       False    0.576923
#              True     0.423077
# Zimbabwe     True     0.558824
#              False    0.441176
# Name: LanguageHaveWorkedWith, Length: 349, dtype: float64

# %%
df[df['Country'] == 'Afghanistan']['LanguageHaveWorkedWith'].nunique()
# Out:
# 56

# %%
residents_per_country = df.groupby('Country')['ResponseId'].count()
python_per_country = df.groupby('Country')['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum())

# %%
final_df = pd.concat([residents_per_country,python_per_country],axis = 1,ignore_index=False,keys = ['Total Residents','Python Knowm']).reset_index()
final_df['% Known'] = (final_df['Python Knowm']/final_df['Total Residents'])*100

# %%
final_df
# Out:
#                                   Country  Total Residents  Python Knowm  \
# 0                             Afghanistan               64            22
# 1                                 Albania               60            19
# 2                                 Algeria               85            35
# 3                                 Andorra               16             5
# 4                                  Angola               13             4
# ..                                    ...              ...           ...
# 180  Venezuela, Bolivarian Republic of...              106            42
# 181                              Viet Nam              390           174
# 182                                 Yemen               20             8
# 183                                Zambia               26            11
# 184                              Zimbabwe               34            19
#
#        % Known
# 0    34.375000
# 1    31.666667
# 2    41.176471
# 3    31.250000
# ...

# %%
df['mean_per_country'] = df.groupby('Country')['CompTotal'].transform('mean')

df[['Country','ResponseId','CompTotal','mean_per_country']]
# Out:
#                             Country  ResponseId     CompTotal  \
# 56322                       Bahamas       56323  5.000000e+46
# 18463  Iran, Islamic Republic of...       18464  1.000000e+21
# 49553      United States of America       49554  1.000000e+16
# 43556                       Romania       43557  1.000000e+16
# 35779                        Canada       35780  1.000000e+15
# ...                             ...         ...           ...
# 88883           Antigua and Barbuda       88884           NaN
# 88940                         Chile       88941           NaN
# 89028                           NaN       89029           NaN
# 89134      United States of America       89135           NaN
# 89159                           NaN       89160           NaN
#
#        mean_per_country
# 56322      5.000000e+46
# 18463      4.255319e+18
# 49553      8.395602e+11
# 43556      2.439024e+13
# 35779      4.734850e+11
# ...                 ...
# 88883      3.500000e+06
# ...

# %%
df.groupby('Country').filter(lambda x : x['CompTotal'].mean()> 500000000000000000)[['Country', 'CompTotal']]
# Out:
#                             Country     CompTotal
# 56322                       Bahamas  5.000000e+46
# 18463  Iran, Islamic Republic of...  1.000000e+21
# 33078  Iran, Islamic Republic of...  1.000000e+11
# 56853  Iran, Islamic Republic of...  1.980000e+10
# 75523  Iran, Islamic Republic of...  1.600000e+10
# ...                             ...           ...
# 12555  Iran, Islamic Republic of...           NaN
# 23567  Iran, Islamic Republic of...           NaN
# 33276  Iran, Islamic Republic of...           NaN
# 35692  Iran, Islamic Republic of...           NaN
# 78050  Iran, Islamic Republic of...           NaN
#
# [579 rows x 2 columns]

# %% [markdown]
# Handling None values

# %%
people = {
    'first' : ['Corey','Jane','John','Chris',np.nan,None,'NA'],
    'last' : ['Schafer','Doe','Doe','Schafer',np.nan,np.nan,'Missing'],
    'email' : ['CoreyMSchafer@gmail.com','JaneDoe@gmail.com','JohnDoe@gmail.com',None,np.nan,'Anonymous@gmail.com','NA'],
    'age' : ['33','55','63','36',None,None,'Missing']
}

df_pep = pd.DataFrame(people)
df_pep
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                      NaN       36
# 4    NaN      NaN                      NaN      NaN
# 5    NaN      NaN      Anonymous@gmail.com      NaN
# 6     NA  Missing                       NA  Missing

# %%
df_pep.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 6     NA  Missing                       NA  Missing

# %%
df_pep.dropna(axis='index',how = 'any')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 6     NA  Missing                       NA  Missing

# %%
df_pep.dropna(axis='index',how = 'all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                      NaN       36
# 5    NaN      NaN      Anonymous@gmail.com      NaN
# 6     NA  Missing                       NA  Missing

# %%
df_pep.dropna(axis='index',how = 'any' , subset = ['first'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                      NaN       36
# 6     NA  Missing                       NA  Missing

# %%
df_pep.replace({'NA' : np.nan, "Missing" : np.nan},inplace= True)
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@gmail.com   55
# 2   John      Doe        JohnDoe@gmail.com   63
# 3  Chris  Schafer                      NaN   36
# 4    NaN      NaN                      NaN  NaN
# 5    NaN      NaN      Anonymous@gmail.com  NaN
# 6    NaN      NaN                      NaN  NaN

# %%
df_pep.dropna(axis='index',how = 'any' , subset = ['first'])
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@gmail.com  55
# 2   John      Doe        JohnDoe@gmail.com  63
# 3  Chris  Schafer                      NaN  36

# %%
df_pep.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df_pep.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@gmail.com  55
# 2   John      Doe        JohnDoe@gmail.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@gmail.com   0
# 6      0        0                        0   0

# %% [markdown]
# Casting

# %%
type(np.nan)
# Out:
# float

# %%
df_pep['age'] = df_pep['age'].astype(float)
df_pep
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@gmail.com  55.0
# 2   John      Doe        JohnDoe@gmail.com  63.0
# 3  Chris  Schafer                      NaN  36.0
# 4    NaN      NaN                      NaN   NaN
# 5    NaN      NaN      Anonymous@gmail.com   NaN
# 6    NaN      NaN                      NaN   NaN

# %%
df_pep['age'].mean()
# Out:
# np.float64(46.75)

# %% [markdown]
# DateSeries

# %%
str = '2020-03-13 06-PM'
dt = pd.to_datetime(str,format='%Y-%m-%d %I-%p')
print(dt)
# Out:
# 2020-03-13 18:00:00

# %%
dt.day_name()
# Out:
# 'Friday'
